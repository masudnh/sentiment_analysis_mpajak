# %% [markdown]
# ## Scraping

# %% [markdown]
# #### Library Installation

# %%
# !pip install google-play-scraper
# Out:
# Collecting google-play-scraper
#   Downloading google_play_scraper-1.2.7-py3-none-any.whl.metadata (50 kB)
# Downloading google_play_scraper-1.2.7-py3-none-any.whl (28 kB)
# Installing collected packages: google-play-scraper
# Successfully installed google-play-scraper-1.2.7

# %% [markdown]
# #### Import Library

# %%
from google_play_scraper import app, Sort, reviews
import pandas as pd
import numpy as np
from pathlib import Path

# %%
# function saving scrapping data to csv
def exportData(filename):
    filepath = Path(f'dataset/{filename}')
    filepath.parent.mkdir(parents=True, exist_ok=True)
    df.to_csv(filepath)

# %%
result, continuation_token = reviews(
    'id.go.pajak.djp',
    lang = 'id',
    country = 'id',
    sort = Sort.NEWEST,
    count = 2000,
    filter_score_with = None
)

df = pd.DataFrame(np.array(result), columns=['review'])
df = df.join(pd.DataFrame(df.pop('review').tolist()))

# %%
df
# Out:
#                                   reviewId          userName  \
# 0     7c89e47a-3752-4f6e-9bbe-f484d94572cb      Faiz Huwaidi
# 1     23d68ef1-de14-4561-88d0-1bc79b290a06      Surya Kusuma
# 2     4fe534e8-e648-49ab-9aa7-b051b8d1c26c        Askar Aska
# 3     fa12c7bd-9a4c-471c-bb9e-d54a4a3f85f9          azam Zam
# 4     5e776387-89da-429c-9c30-4d0aef6cf603     Rendi Renaldi
# ...                                    ...               ...
# 1995  5fafbf33-6787-4cd7-966f-6adf61f94c1e     Bimojaya Jaya
# 1996  057787f0-6874-4425-b20a-8f873dc10627  Muhaemin Wasalam
# 1997  862dfdd6-3bf6-487f-8b85-d8a4338d65f8      Gamer Pemula
# 1998  aa89637a-48a3-49fb-8eb4-d3ff666312d6               A c
# 1999  4b5d7f0c-0b09-4a2b-b73d-cd8095ea0ab9  Herlina Hidayati
#
#                                               userImage  \
# 0     https://play-lh.googleusercontent.com/a-/ALV-U...
# 1     https://play-lh.googleusercontent.com/a-/ALV-U...
# 2     https://play-lh.googleusercontent.com/a-/ALV-U...
# 3     https://play-lh.googleusercontent.com/a-/ALV-U...
# 4     https://play-lh.googleusercontent.com/a/ACg8oc...
# ...                                                 ...
# 1995  https://play-lh.googleusercontent.com/a-/ALV-U...
# 1996  https://play-lh.googleusercontent.com/a-/ALV-U...
# 1997  https://play-lh.googleusercontent.com/a-/ALV-U...
# 1998  https://play-lh.googleusercontent.com/a/ACg8oc...
# 1999  https://play-lh.googleusercontent.com/a-/ALV-U...
#
#                                                 content  score  thumbsUpCount  \
# 0                  Lemot banget ngirim kode OTP nya ajg      1              0
# 1     Daftar pajak email aktivasi sudah, ehh pas ner...      1              0
# 2     Pas Nunggu Kode OTP nya emng GK lama,TPI GK ta...      3              0
# 3                 Sangat cocok untuk melihat pajak saya      5              0
# 4                                  ngabisin pulsa doang      1              0
# ...                                                 ...    ...            ...
# 1995        Biasanya lancar skrg malah gak bisa dipake.      1              0
# 1996  efin aja harus ke kantor,..thn 2023 masih kaku...      1              0
# 1997  Sekelas kementrian perpajakan bikin aplikasi a...      1              0
# 1998  Sangat miris ya, app penting dan dikelola peme...      1             21
# 1999  Begitu masuk akun langsung eror tdk bisa dibuk...      1              1
#
#      reviewCreatedVersion                  at replyContent repliedAt  \
# 0                   1.4.0 2024-09-23 12:47:06         None      None
# 1                   1.4.0 2024-09-23 11:29:20         None      None
# 2                   1.4.0 2024-09-22 23:26:55         None      None
# 3                   1.4.0 2024-09-22 13:31:47         None      None
# 4                   1.4.0 2024-09-22 00:08:03         None      None
# ...                   ...                 ...          ...       ...
# 1995                1.2.3 2023-06-06 11:13:30         None      None
# 1996                 None 2023-06-05 14:54:51         None      None
# 1997                1.2.3 2023-06-05 14:10:30         None      None
# 1998                1.2.3 2023-06-05 14:01:15         None      None
# 1999                1.2.3 2023-06-05 13:37:38         None      None
#
#      appVersion
# 0         1.4.0
# 1         1.4.0
# 2         1.4.0
# 3         1.4.0
# 4         1.4.0
# ...         ...
# 1995      1.2.3
# 1996       None
# 1997      1.2.3
# 1998      1.2.3
# 1999      1.2.3
#
# [2000 rows x 11 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   reviewId              2000 non-null   object
#  1   userName              2000 non-null   object
#  2   userImage             2000 non-null   object
#  3   content               2000 non-null   object
#  4   score                 2000 non-null   int64
#  5   thumbsUpCount         2000 non-null   int64
#  6   reviewCreatedVersion  1591 non-null   object
#  7   at                    2000 non-null   datetime64[ns]
#  8   replyContent          0 non-null      object
#  9   repliedAt             0 non-null      object
#  10  appVersion            1591 non-null   object
# dtypes: datetime64[ns](1), int64(2), object(8)
# memory usage: 172.0+ KB

# %%
df.columns
# Out:
# Index(['reviewId', 'userName', 'userImage', 'content', 'score',
#        'thumbsUpCount', 'reviewCreatedVersion', 'at', 'replyContent',
#        'repliedAt', 'appVersion'],
#       dtype='object')

# %% [markdown]
# ### Download as CSV

# %%
exportData('data_of_mpajak_reviews_2000-2.csv')
